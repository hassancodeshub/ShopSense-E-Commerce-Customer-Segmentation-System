# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("smartcart_customers.csv")

# %%
data.sample(5)
# Out:
#         ID  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 965   7801        1959  Graduation       Together  54753.0        0         1
# 1646  5177        1974      Master        Married  58494.0        0         1
# 949   2882        1975    2n Cycle       Divorced  67893.0        0         1
# 1396  8663        1974  Graduation       Divorced  39996.0        1         1
# 942   6810        1983  Graduation       Divorced  82025.0        0         0
#
#      Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 965   12-09-2013       87       197  ...                7                59
# 1646  12-12-2013       56       298  ...                4                 0
# 949   01-10-2012       31       711  ...               49                18
# 1396  22-05-2014       85        11  ...                0                 0
# 942   28-05-2013       76       267  ...               48                70
#
#       MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# 965            131                  3                5                    2
# 1646            19                  2                6                    2
# 949             47                  2                3                    2
# 1396             1                  1                1                    0
# 942             98                  1                3                    2
#
#       NumStorePurchases  NumWebVisitsMonth  Complain  Response
# 965                  11                  4         0         0
# 1646                  6                  6         0         0
# 949                   9                  8         0         0
# 1396                  2                  6         0         0
# 942                   6                  1         0         1
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  Complain             2240 non-null   int64
#  21  Response             2240 non-null   int64
# dtypes: float64(1), int64(18), object(3)
# memory usage: 385.1+ KB

# %%
data.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Complain                0
# Response                0
# dtype: int64

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## 1. Handling Missing Values

# %%
data["Income"] = data["Income"].fillna(data["Income"].median())

# %%
data.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Complain               0
# Response               0
# dtype: int64
